# %%
import pandas as pd

# %%
import datetime

# %%
df_admin = pd.read_excel("NZ_Admin_JOBS.xlsx", header = None)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                                       3  \
# 0     location: Bay of PlentyBay of Plentyarea: Taur...
# 1     location: Bay of PlentyBay of Plentyarea: Taur...
# 2                            location: AucklandAuckland
# 3     location: SouthlandSouthlandarea: Invercargill...
# 4     location: CanterburyCanterburyarea: Christchur...
# ...                                                 ...
# 2703  location: AucklandAucklandarea: Auckland Centr...
# 2704  location: WellingtonWellingtonarea: Wellington...
# 2705  location: WaikatoWaikatoarea: HamiltonHamilton...
# 2706  location: WaikatoWaikatoarea: HamiltonHamilton...
# 2707                     location: WellingtonWellington
#
#                                    4  \
# 0     Featured,at,Private Advertiser
# 1                        Featured,at
# 2                          4d ago,at
# 3                          1h ago,at
# 4       4d ago,at,Private Advertiser
# ...                              ...
# 2703                      27d ago,at
# 2704                      27d ago,at
# 2705                      20d ago,at
# 2706                      28d ago,at
# 2707                      26d ago,at
#
#                                                       5
# 0     classification: Administration & Office Suppor...
# 1     classification: Administration & Office Suppor...
# 2     classification: Administration & Office Suppor...
# 3     classification: Administration & Office Suppor...
# 4     classification: Administration & Office Suppor...
# ...                                                 ...
# 2703  classification: Administration & Office Suppor...
# 2704                            Competitive hourly rate
# 2705                        Competitive hourly rates $$
# 2706                        Competitive hourly rates $$
# 2707  classification: Administration & Office Suppor...
#
# [2708 rows x 6 columns]

# %%
df_admin[['Location', 'Area']] = df_admin[3].str.split('area:', expand=True) 
## If using expand=True, Series and Index callers return DataFrame and MultiIndex objects, respectively.
## expand=True - 直接将分列后的结果转换成DataFrame.

# %%
df_admin[['Location', 'Area']]
# Out:
#                                   Location  \
# 0     location: Bay of PlentyBay of Plenty
# 1     location: Bay of PlentyBay of Plenty
# 2               location: AucklandAuckland
# 3             location: SouthlandSouthland
# 4           location: CanterburyCanterbury
# ...                                    ...
# 2703            location: AucklandAuckland
# 2704        location: WellingtonWellington
# 2705              location: WaikatoWaikato
# 2706              location: WaikatoWaikato
# 2707        location: WellingtonWellington
#
#                                                    Area
# 0                                      TaurangaTauranga
# 1                                      TaurangaTauranga
# 2                                                  None
# 3                              InvercargillInvercargill
# 4                              ChristchurchChristchurch
# ...                                                 ...
# 2703                   Auckland CentralAuckland Central
# 2704   Wellington CentralWellington Central,Competit...
# 2705       HamiltonHamilton,Competitive hourly rates $$
# 2706       HamiltonHamilton,Competitive hourly rates $$
# 2707                                               None
#
# [2708 rows x 2 columns]

# %%
df_admin['Location'].isna().sum()
# Out:
# 0

# %%
df_admin['Location'] = df_admin['Location'].apply(lambda x: x[9:]) 
## apply与lambda合用，修改某列的字符，只保留后9位之后内容)

# %%
df_admin['Location']
# Out:
# 0        Bay of PlentyBay of Plenty
# 1        Bay of PlentyBay of Plenty
# 2                  AucklandAuckland
# 3                SouthlandSouthland
# 4              CanterburyCanterbury
#                    ...
# 2703               AucklandAuckland
# 2704           WellingtonWellington
# 2705                 WaikatoWaikato
# 2706                 WaikatoWaikato
# 2707           WellingtonWellington
# Name: Location, Length: 2708, dtype: object

# %%
def deduplication(x):
    mid = len(x)//2
    if x!='unknown':
        return x[:mid+1]
    else:
        return 'unknown'

# %%
df_admin['Location'] = df_admin['Location'].apply(deduplication)

# %%
df_admin['Location']
# Out:
# 0        Bay of Plenty
# 1        Bay of Plenty
# 2             Auckland
# 3            Southland
# 4           Canterbury
#              ...
# 2703          Auckland
# 2704        Wellington
# 2705           Waikato
# 2706           Waikato
# 2707        Wellington
# Name: Location, Length: 2708, dtype: object

# %%
df_admin['Area'].isna().sum()
# Out:
# 541

# %%
df_admin['Area']
# Out:
# 0                                        TaurangaTauranga
# 1                                        TaurangaTauranga
# 2                                                    None
# 3                                InvercargillInvercargill
# 4                                ChristchurchChristchurch
#                               ...
# 2703                     Auckland CentralAuckland Central
# 2704     Wellington CentralWellington Central,Competit...
# 2705         HamiltonHamilton,Competitive hourly rates $$
# 2706         HamiltonHamilton,Competitive hourly rates $$
# 2707                                                 None
# Name: Area, Length: 2708, dtype: object

# %%
df_admin['Area'].fillna(value='unknown',inplace = True) 
## in place - 所用的方法是否改变原数据。

# %%
df_admin['Area']
# Out:
# 0                                        TaurangaTauranga
# 1                                        TaurangaTauranga
# 2                                                 unknown
# 3                                InvercargillInvercargill
# 4                                ChristchurchChristchurch
#                               ...
# 2703                     Auckland CentralAuckland Central
# 2704     Wellington CentralWellington Central,Competit...
# 2705         HamiltonHamilton,Competitive hourly rates $$
# 2706         HamiltonHamilton,Competitive hourly rates $$
# 2707                                              unknown
# Name: Area, Length: 2708, dtype: object

# %%
df_admin['Area'] = df_admin['Area'].apply(deduplication)

# %%
df_admin['Area']
# Out:
# 0                              Tauranga
# 1                              Tauranga
# 2                               unknown
# 3                          Invercargill
# 4                          Christchurch
#                      ...
# 2703                   Auckland Central
# 2704     Wellington CentralWellington C
# 2705             HamiltonHamilton,Compe
# 2706             HamiltonHamilton,Compe
# 2707                            unknown
# Name: Area, Length: 2708, dtype: object

# %%
def apply_Area(x):
    if ',Compe' in x:
        return df_admin['Area'].apply(lambda x: x[:-6])
    else:
        return x

# %%
df_admin['Area'] = df_admin['Area'].apply(apply_Area)

# %%
df_admin['Area']
# Out:
# 0                                                Tauranga
# 1                                                Tauranga
# 2                                                 unknown
# 3                                            Invercargill
# 4                                            Christchurch
#                               ...
# 2703                                     Auckland Central
# 2704                       Wellington CentralWellington C
# 2705    0                              Ta
# 1           ...
# 2706    0                              Ta
# 1           ...
# 2707                                              unknown
# Name: Area, Length: 2708, dtype: object

# %%
df_admin['Area'].isna().sum()
# Out:
# 0

# %%
df_admin.drop(3, axis = 1, inplace = True) 
## df.drop(name, axis=1) 代表将name对应的列标签（们）沿着水平的方向依次删掉

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                    4  \
# 0     Featured,at,Private Advertiser
# 1                        Featured,at
# 2                          4d ago,at
# 3                          1h ago,at
# 4       4d ago,at,Private Advertiser
# ...                              ...
# 2703                      27d ago,at
# 2704                      27d ago,at
# 2705                      20d ago,at
# 2706                      28d ago,at
# 2707                      26d ago,at
#
#                                                       5        Location  \
# 0     classification: Administration & Office Suppor...   Bay of Plenty
# 1     classification: Administration & Office Suppor...   Bay of Plenty
# 2     classification: Administration & Office Suppor...        Auckland
# 3     classification: Administration & Office Suppor...       Southland
# 4     classification: Administration & Office Suppor...      Canterbury
# ...                                                 ...             ...
# 2703  classification: Administration & Office Suppor...        Auckland
# 2704                            Competitive hourly rate      Wellington
# 2705                        Competitive hourly rates $$         Waikato
# 2706                        Competitive hourly rates $$         Waikato
# 2707  classification: Administration & Office Suppor...      Wellington
#
#                                                    Area
# 0                                              Tauranga
# 1                                              Tauranga
# 2                                               unknown
# 3                                          Invercargill
# 4                                          Christchurch
# ...                                                 ...
# 2703                                   Auckland Central
# 2704                     Wellington CentralWellington C
# 2705  0                              Ta
# 1           ...
# 2706  0                              Ta
# 1           ...
# 2707                                            unknown
#
# [2708 rows x 7 columns]

# %%
df_admin[['Subclassification','Classification']] = df_admin[5].str.split('subClassification:', expand = True)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                    4  \
# 0     Featured,at,Private Advertiser
# 1                        Featured,at
# 2                          4d ago,at
# 3                          1h ago,at
# 4       4d ago,at,Private Advertiser
# ...                              ...
# 2703                      27d ago,at
# 2704                      27d ago,at
# 2705                      20d ago,at
# 2706                      28d ago,at
# 2707                      26d ago,at
#
#                                                       5        Location  \
# 0     classification: Administration & Office Suppor...   Bay of Plenty
# 1     classification: Administration & Office Suppor...   Bay of Plenty
# 2     classification: Administration & Office Suppor...        Auckland
# 3     classification: Administration & Office Suppor...       Southland
# 4     classification: Administration & Office Suppor...      Canterbury
# ...                                                 ...             ...
# 2703  classification: Administration & Office Suppor...        Auckland
# 2704                            Competitive hourly rate      Wellington
# 2705                        Competitive hourly rates $$         Waikato
# 2706                        Competitive hourly rates $$         Waikato
# 2707  classification: Administration & Office Suppor...      Wellington
#
#                                                    Area  \
# 0                                              Tauranga
# 1                                              Tauranga
# 2                                               unknown
# 3                                          Invercargill
# 4                                          Christchurch
# ...                                                 ...
# 2703                                   Auckland Central
# 2704                     Wellington CentralWellington C
# 2705  0                              Ta
# 1           ...
# 2706  0                              Ta
# 1           ...
# 2707                                            unknown
#
#                                       Subclassification  \
# 0     classification: Administration & Office Suppor...
# 1     classification: Administration & Office Suppor...
# 2     classification: Administration & Office Suppor...
# 3     classification: Administration & Office Suppor...
# 4     classification: Administration & Office Suppor...
# ...                                                 ...
# 2703  classification: Administration & Office Suppor...
# 2704                            Competitive hourly rate
# 2705                        Competitive hourly rates $$
# 2706                        Competitive hourly rates $$
# 2707  classification: Administration & Office Suppor...
#
#                                          Classification
# 0                    Office ManagementOffice Management
# 1                            ReceptionistsReceptionists
# 2                                            OtherOther
# 3      Administrative AssistantsAdministrative Assis...
# 4      Client & Sales AdministrationClient & Sales A...
# ...                                                 ...
# 2703   Client & Sales AdministrationClient & Sales A...
# 2704                                               None
# 2705                                               None
# 2706                                               None
# 2707           PA, EA & SecretarialPA, EA & Secretarial
#
# [2708 rows x 9 columns]

# %%
df_admin['Subclassification'].isna().sum()
# Out:
# 0

# %%
df_admin['Classification'].isna().sum()
# Out:
# 603

# %%
df_admin['Classification'].fillna(value='unknown',inplace = True)

# %%
df_admin['Classification']
# Out:
# 0                      Office ManagementOffice Management
# 1                              ReceptionistsReceptionists
# 2                                              OtherOther
# 3        Administrative AssistantsAdministrative Assis...
# 4        Client & Sales AdministrationClient & Sales A...
#                               ...
# 2703     Client & Sales AdministrationClient & Sales A...
# 2704                                              unknown
# 2705                                              unknown
# 2706                                              unknown
# 2707             PA, EA & SecretarialPA, EA & Secretarial
# Name: Classification, Length: 2708, dtype: object

# %%
df_admin['Classification'] = df_admin['Classification'].apply(deduplication)

# %%
df_admin['Classification']
# Out:
# 0                    Office Management
# 1                        Receptionists
# 2                                Other
# 3            Administrative Assistants
# 4        Client & Sales Administration
#                      ...
# 2703     Client & Sales Administration
# 2704                           unknown
# 2705                           unknown
# 2706                           unknown
# 2707              PA, EA & Secretarial
# Name: Classification, Length: 2708, dtype: object

# %%
df_admin.drop(5, axis = 1, inplace = True)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                    4        Location  \
# 0     Featured,at,Private Advertiser   Bay of Plenty
# 1                        Featured,at   Bay of Plenty
# 2                          4d ago,at        Auckland
# 3                          1h ago,at       Southland
# 4       4d ago,at,Private Advertiser      Canterbury
# ...                              ...             ...
# 2703                      27d ago,at        Auckland
# 2704                      27d ago,at      Wellington
# 2705                      20d ago,at         Waikato
# 2706                      28d ago,at         Waikato
# 2707                      26d ago,at      Wellington
#
#                                                    Area  \
# 0                                              Tauranga
# 1                                              Tauranga
# 2                                               unknown
# 3                                          Invercargill
# 4                                          Christchurch
# ...                                                 ...
# 2703                                   Auckland Central
# 2704                     Wellington CentralWellington C
# 2705  0                              Ta
# 1           ...
# 2706  0                              Ta
# 1           ...
# 2707                                            unknown
#
#                                       Subclassification  \
# 0     classification: Administration & Office Suppor...
# 1     classification: Administration & Office Suppor...
# 2     classification: Administration & Office Suppor...
# 3     classification: Administration & Office Suppor...
# 4     classification: Administration & Office Suppor...
# ...                                                 ...
# 2703  classification: Administration & Office Suppor...
# 2704                            Competitive hourly rate
# 2705                        Competitive hourly rates $$
# 2706                        Competitive hourly rates $$
# 2707  classification: Administration & Office Suppor...
#
#                       Classification
# 0                  Office Management
# 1                      Receptionists
# 2                              Other
# 3          Administrative Assistants
# 4      Client & Sales Administration
# ...                              ...
# 2703   Client & Sales Administration
# 2704                         unknown
# 2705                         unknown
# 2706                         unknown
# 2707            PA, EA & Secretarial
#
# [2708 rows x 8 columns]

# %%
df_admin[['Posted time','Featured at']] = df_admin[4].str.split(',', expand = True)[[0,2]]

# %%
df_admin[['Posted time','Featured at']]
# Out:
#      Posted time         Featured at
# 0       Featured  Private Advertiser
# 1       Featured                None
# 2         4d ago                None
# 3         1h ago                None
# 4         4d ago  Private Advertiser
# ...          ...                 ...
# 2703     27d ago                None
# 2704     27d ago                None
# 2705     20d ago                None
# 2706     28d ago                None
# 2707     26d ago                None
#
# [2708 rows x 2 columns]

# %%
df_admin.drop(4, axis = 1, inplace = True)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2        Location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                                    Area  \
# 0                                              Tauranga
# 1                                              Tauranga
# 2                                               unknown
# 3                                          Invercargill
# 4                                          Christchurch
# ...                                                 ...
# 2703                                   Auckland Central
# 2704                     Wellington CentralWellington C
# 2705  0                              Ta
# 1           ...
# 2706  0                              Ta
# 1           ...
# 2707                                            unknown
#
#                                       Subclassification  \
# 0     classification: Administration & Office Suppor...
# 1     classification: Administration & Office Suppor...
# 2     classification: Administration & Office Suppor...
# 3     classification: Administration & Office Suppor...
# 4     classification: Administration & Office Suppor...
# ...                                                 ...
# 2703  classification: Administration & Office Suppor...
# 2704                            Competitive hourly rate
# 2705                        Competitive hourly rates $$
# 2706                        Competitive hourly rates $$
# 2707  classification: Administration & Office Suppor...
#
#                       Classification Posted time         Featured at
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured                None
# 2                              Other      4d ago                None
# 3          Administrative Assistants      1h ago                None
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago                None
# 2704                         unknown     27d ago                None
# 2705                         unknown     20d ago                None
# 2706                         unknown     28d ago                None
# 2707            PA, EA & Secretarial     26d ago                None
#
# [2708 rows x 9 columns]

# %%
df_admin['Posted time'].isna().sum()
# Out:
# 0

# %%
df_admin['Featured at'].isna().sum()
# Out:
# 2686

# %%
df_admin['Featured at'].fillna('unknown', inplace = True)

# %%
df_admin['Featured at']
# Out:
# 0       Private Advertiser
# 1                  unknown
# 2                  unknown
# 3                  unknown
# 4       Private Advertiser
#                ...
# 2703               unknown
# 2704               unknown
# 2705               unknown
# 2706               unknown
# 2707               unknown
# Name: Featured at, Length: 2708, dtype: object

# %%
def apply_salary(x):
    if 'classification:' in x:
        return 'unknown'
    else:
        return x

# %%
df_admin['Salary'] = df_admin['Subclassification'].apply(apply_salary)

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2        Location           Area  \
# 0                                       NaN   Bay of Plenty       Tauranga
# 1                      Avenues Orthodontics   Bay of Plenty       Tauranga
# 2                        New Zealand Police        Auckland        unknown
# 3  Kew Pacific Island Early Learning Centre       Southland   Invercargill
# 4                                       NaN      Canterbury   Christchurch
#
#                                    Subclassification  \
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...
#
#                    Classification Posted time         Featured at   Salary
# 0               Office Management    Featured  Private Advertiser  unknown
# 1                   Receptionists    Featured             unknown  unknown
# 2                           Other      4d ago             unknown  unknown
# 3       Administrative Assistants      1h ago             unknown  unknown
# 4   Client & Sales Administration      4d ago  Private Advertiser  unknown

# %%
df_admin['Salary']
# Out:
# 0                           unknown
# 1                           unknown
# 2                           unknown
# 3                           unknown
# 4                           unknown
#                    ...
# 2703                        unknown
# 2704        Competitive hourly rate
# 2705    Competitive hourly rates $$
# 2706    Competitive hourly rates $$
# 2707                        unknown
# Name: Salary, Length: 2708, dtype: object

# %%
def apply_classification(x):
    if 'classification' in x:
        return x[15:]
    else:
        return 'unknown'

# %%
df_admin['Subclassification']=df_admin['Subclassification'].apply(apply_classification)

# %%
df_admin['Subclassification']
# Out:
# 0        Administration & Office SupportAdministration...
# 1        Administration & Office SupportAdministration...
# 2        Administration & Office SupportAdministration...
# 3        Administration & Office SupportAdministration...
# 4        Administration & Office SupportAdministration...
#                               ...
# 2703     Administration & Office SupportAdministration...
# 2704                                              unknown
# 2705                                              unknown
# 2706                                              unknown
# 2707     Administration & Office SupportAdministration...
# Name: Subclassification, Length: 2708, dtype: object

# %%
df_admin[['Class1','Class2','Class3']] = df_admin['Subclassification'].str.split('&', expand = True).fillna('unknown')

# %%
df_admin.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2        Location           Area  \
# 0                                       NaN   Bay of Plenty       Tauranga
# 1                      Avenues Orthodontics   Bay of Plenty       Tauranga
# 2                        New Zealand Police        Auckland        unknown
# 3  Kew Pacific Island Early Learning Centre       Southland   Invercargill
# 4                                       NaN      Canterbury   Christchurch
#
#                                    Subclassification  \
# 0   Administration & Office SupportAdministration...
# 1   Administration & Office SupportAdministration...
# 2   Administration & Office SupportAdministration...
# 3   Administration & Office SupportAdministration...
# 4   Administration & Office SupportAdministration...
#
#                    Classification Posted time         Featured at   Salary  \
# 0               Office Management    Featured  Private Advertiser  unknown
# 1                   Receptionists    Featured             unknown  unknown
# 2                           Other      4d ago             unknown  unknown
# 3       Administrative Assistants      1h ago             unknown  unknown
# 4   Client & Sales Administration      4d ago  Private Advertiser  unknown
#
#              Class1                          Class2           Class3
# 0   Administration    Office SupportAdministration    Office Support
# 1   Administration    Office SupportAdministration    Office Support
# 2   Administration    Office SupportAdministration    Office Support
# 3   Administration    Office SupportAdministration    Office Support
# 4   Administration    Office SupportAdministration    Office Support

# %%
df_admin.drop('Subclassification', axis = 1, inplace = True)

# %%
df_admin
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                       1  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                              2        Location  \
# 0                                          NaN   Bay of Plenty
# 1                         Avenues Orthodontics   Bay of Plenty
# 2                           New Zealand Police        Auckland
# 3     Kew Pacific Island Early Learning Centre       Southland
# 4                                          NaN      Canterbury
# ...                                        ...             ...
# 2703                     Hays Talent Solutions        Auckland
# 2704                    one eighty recruitment      Wellington
# 2705                     Asset Recruitment Ltd         Waikato
# 2706                     Asset Recruitment Ltd         Waikato
# 2707                    Alpha Recruitment - NZ      Wellington
#
#                                                    Area  \
# 0                                              Tauranga
# 1                                              Tauranga
# 2                                               unknown
# 3                                          Invercargill
# 4                                          Christchurch
# ...                                                 ...
# 2703                                   Auckland Central
# 2704                     Wellington CentralWellington C
# 2705  0                              Ta
# 1           ...
# 2706  0                              Ta
# 1           ...
# 2707                                            unknown
#
#                       Classification Posted time         Featured at  \
# 0                  Office Management    Featured  Private Advertiser
# 1                      Receptionists    Featured             unknown
# 2                              Other      4d ago             unknown
# 3          Administrative Assistants      1h ago             unknown
# 4      Client & Sales Administration      4d ago  Private Advertiser
# ...                              ...         ...                 ...
# 2703   Client & Sales Administration     27d ago             unknown
# 2704                         unknown     27d ago             unknown
# 2705                         unknown     20d ago             unknown
# 2706                         unknown     28d ago             unknown
# 2707            PA, EA & Secretarial     26d ago             unknown
#
#                            Salary            Class1  \
# 0                         unknown   Administration
# 1                         unknown   Administration
# 2                         unknown   Administration
# 3                         unknown   Administration
# 4                         unknown   Administration
# ...                           ...               ...
# 2703                      unknown   Administration
# 2704      Competitive hourly rate           unknown
# 2705  Competitive hourly rates $$           unknown
# 2706  Competitive hourly rates $$           unknown
# 2707                      unknown   Administration
#
#                               Class2           Class3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                         unknown          unknown
# 2705                         unknown          unknown
# 2706                         unknown          unknown
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 12 columns]

# %%
df_admin.rename(columns ={0:'Job title',1:'Web add',2:'Co name'}, inplace = True )

# %%
df_admin.head()
# Out:
#                               Job title  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                              Web add  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Co name        Location           Area  \
# 0                                       NaN   Bay of Plenty       Tauranga
# 1                      Avenues Orthodontics   Bay of Plenty       Tauranga
# 2                        New Zealand Police        Auckland        unknown
# 3  Kew Pacific Island Early Learning Centre       Southland   Invercargill
# 4                                       NaN      Canterbury   Christchurch
#
#                    Classification Posted time         Featured at   Salary  \
# 0               Office Management    Featured  Private Advertiser  unknown
# 1                   Receptionists    Featured             unknown  unknown
# 2                           Other      4d ago             unknown  unknown
# 3       Administrative Assistants      1h ago             unknown  unknown
# 4   Client & Sales Administration      4d ago  Private Advertiser  unknown
#
#              Class1                          Class2           Class3
# 0   Administration    Office SupportAdministration    Office Support
# 1   Administration    Office SupportAdministration    Office Support
# 2   Administration    Office SupportAdministration    Office Support
# 3   Administration    Office SupportAdministration    Office Support
# 4   Administration    Office SupportAdministration    Office Support

# %%
df_admin['Co name'].fillna(df_admin['Featured at'], inplace = True)

# %%
df_admin['Co name']
# Out:
# 0                             Private Advertiser
# 1                           Avenues Orthodontics
# 2                             New Zealand Police
# 3       Kew Pacific Island Early Learning Centre
# 4                             Private Advertiser
#                           ...
# 2703                       Hays Talent Solutions
# 2704                      one eighty recruitment
# 2705                       Asset Recruitment Ltd
# 2706                       Asset Recruitment Ltd
# 2707                      Alpha Recruitment - NZ
# Name: Co name, Length: 2708, dtype: object

# %%
df_admin.drop(['Featured at'], axis = 1, inplace = True)

# %%
df_admin.head()
# Out:
#                               Job title  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                              Web add  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Co name        Location           Area  \
# 0                        Private Advertiser   Bay of Plenty       Tauranga
# 1                      Avenues Orthodontics   Bay of Plenty       Tauranga
# 2                        New Zealand Police        Auckland        unknown
# 3  Kew Pacific Island Early Learning Centre       Southland   Invercargill
# 4                        Private Advertiser      Canterbury   Christchurch
#
#                    Classification Posted time   Salary            Class1  \
# 0               Office Management    Featured  unknown   Administration
# 1                   Receptionists    Featured  unknown   Administration
# 2                           Other      4d ago  unknown   Administration
# 3       Administrative Assistants      1h ago  unknown   Administration
# 4   Client & Sales Administration      4d ago  unknown   Administration
#
#                            Class2           Class3
# 0   Office SupportAdministration    Office Support
# 1   Office SupportAdministration    Office Support
# 2   Office SupportAdministration    Office Support
# 3   Office SupportAdministration    Office Support
# 4   Office SupportAdministration    Office Support

# %%
df_admin['Posted time']=df_admin['Posted time'].str.extract('(\d+[a-z])') 

## \d - Digital, matches any digit character (0 - 9)
## a-z - Matches a character in the range "a" to "z"

# %%
df_admin['Posted time']
# Out:
# 0       NaN
# 1       NaN
# 2        4d
# 3        1h
# 4        4d
#        ...
# 2703    27d
# 2704    27d
# 2705    20d
# 2706    28d
# 2707    26d
# Name: Posted time, Length: 2708, dtype: object

# %%
df_admin['Posted time'].fillna('unknown', inplace = True)

# %%
df_admin['Posted time']
# Out:
# 0       unknown
# 1       unknown
# 2            4d
# 3            1h
# 4            4d
#          ...
# 2703        27d
# 2704        27d
# 2705        20d
# 2706        28d
# 2707        26d
# Name: Posted time, Length: 2708, dtype: object
